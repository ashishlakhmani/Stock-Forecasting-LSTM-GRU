# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
start_date = '2011-01-01'
end_date = '2023-08-31'

# %%
aapl=yf.download('AAPL',start=start_date, end=end_date)[['Close']]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
aaplTrain=aapl['2011':'2023-06'];
aaplTest=aapl['2023-07':]

# %%
training_set = aaplTrain.iloc[:,[0]].values

# %%
training_set.shape
# Out:
# (3144, 1)

# %%
training_set
# Out:
# array([[ 11.77035713],
#        [ 11.83178616],
#        [ 11.92857075],
#        ...,
#        [189.25      ],
#        [189.58999634],
#        [193.97000122]])

# %% [markdown]
# ### Visualizing non-normalized data

# %%
plt.figure(figsize=(10,5))
aaplTrain.Close.plot(label='AAPl');
plt.ylabel('Close')
plt.legend()

# %%
#scaling the datset- normalization
from sklearn.preprocessing import MinMaxScaler;
msc=MinMaxScaler(feature_range=(0,1))
training_set_scaled=msc.fit_transform(training_set);

# %% [markdown]
# ### Visualizing normalized data

# %%
plt.figure(figsize=(10,5))
plt.xlabel('Date');
plt.ylabel('Close');
plt.plot(aaplTrain.index,training_set_scaled,label='AAPL');
plt.legend()

# %% [markdown]
# ### Creating a data structure with 120 timesteps and 1 output

# %%
X_train=[];
y_train=[];
for i in range(120,len(training_set_scaled)):
    X_train.append(training_set_scaled[i-120:i,0]);
    y_train.append(training_set_scaled[i,0]);
X_train,y_train=np.array(X_train), np.array(y_train)

# %%
X_train=X_train.reshape(X_train.shape[0],X_train.shape[1],-1)

# %%
print(X_train.shape)
# Out:
# (3024, 120, 1)

# %% [markdown]
# ### Building GRU

# %%
from keras.layers import Input
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import GRU
from keras.layers import TimeDistributed
from keras.layers import Dropout
from keras import Model

# %%
input=Input(shape=(X_train.shape[1],1))
firstlayer=GRU(units=50, return_sequences=True)(input)
d=Dropout(0.2)(firstlayer)
secondlayer=GRU(units=50, return_sequences=True)(d);
d=Dropout(0.2)(secondlayer)
thirdlayer=GRU(units=50, return_sequences=True)(d);
d=Dropout(0.2)(thirdlayer)
fourthlayer=GRU(units=50, return_sequences=False)(d);
d=Dropout(0.2)(fourthlayer);
finallayer=Dense(units=1)(d);
grumodel=Model(input,finallayer)

# %%
grumodel.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
grumodel.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 95/95 [==============================] - 17s 125ms/step - loss: 0.0126
# Epoch 2/100
# 95/95 [==============================] - 15s 163ms/step - loss: 0.0022
# Epoch 3/100
# 95/95 [==============================] - 18s 192ms/step - loss: 0.0021
# Epoch 4/100
# 95/95 [==============================] - 19s 199ms/step - loss: 0.0018
# Epoch 5/100
# 95/95 [==============================] - 19s 197ms/step - loss: 0.0018
# Epoch 6/100
# 95/95 [==============================] - 21s 218ms/step - loss: 0.0014
# Epoch 7/100
# 95/95 [==============================] - 30s 316ms/step - loss: 0.0015
# Epoch 8/100
# 95/95 [==============================] - 34s 356ms/step - loss: 0.0015
# Epoch 9/100
# 95/95 [==============================] - 27s 287ms/step - loss: 0.0015
# Epoch 10/100
# 95/95 [==============================] - 29s 303ms/step - loss: 0.0013
# Epoch 11/100
# 95/95 [==============================] - 28s 294ms/step - loss: 0.0015
# Epoch 12/100
# 95/95 [==============================] - 30s 312ms/step - loss: 0.0014
# Epoch 13/100
# 95/95 [==============================] - 31s 322ms/step - loss: 0.0013
# Epoch 14/100
# 95/95 [==============================] - 35s 364ms/step - loss: 0.0014
# Epoch 15/100
# 95/95 [==============================] - 37s 389ms/step - loss: 0.0013
# Epoch 16/100
# 95/95 [==============================] - 35s 365ms/step - loss: 0.0014
# Epoch 17/100
# 95/95 [==============================] - 36s 376ms/step - loss: 0.0011
# Epoch 18/100
summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 120, 1)]          0
#
#  gru (GRU)                   (None, 120, 50)           7950
#
#  dropout (Dropout)           (None, 120, 50)           0
#
#  gru_1 (GRU)                 (None, 120, 50)           15300
#
#  dropout_1 (Dropout)         (None, 120, 50)           0
#
#  gru_2 (GRU)                 (None, 120, 50)           15300
#
#  dropout_2 (Dropout)         (None, 120, 50)           0
#
#  gru_3 (GRU)                 (None, 50)                15300
#
#  dropout_3 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 53,901
# Trainable params: 53,901
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Testing our model

# %%
dataset_test = aaplTest
real_stock_price = dataset_test.iloc[:, [0]].values

# %%
real_stock_price
# Out:
# array([[192.46000671],
#        [191.33000183],
#        [191.80999756],
#        [190.67999268],
#        [188.61000061],
#        [188.08000183],
#        [189.77000427],
#        [190.53999329],
#        [190.69000244],
#        [193.99000549],
#        [193.72999573],
#        [195.1000061 ],
#        [193.13000488],
#        [191.94000244],
#        [192.75      ],
#        [193.61999512],
#        [194.5       ],
#        [193.22000122],
#        [195.83000183],
#        [196.44999695],
#        [195.61000061],
#        [192.58000183],
#        [191.16999817],
#        [181.99000549],
#        [178.8500061 ],
#        [179.80000305],
#        [178.19000244],
#        [177.97000122],
#        [177.78999329],
#        [179.46000671],
#        [177.44999695],
#        [176.57000732],
#        [174.        ],
#        [174.49000549],
#        [175.83999634],
#        [177.22999573],
#        [181.11999512],
#        [176.38000488],
#        [178.61000061],
#        [180.19000244],
#        [184.11999512]])

# %% [markdown]
# ### Visualizing AAPL test data before normalization

# %%
dataset_test.Close.plot(label='AAPL')
plt.legend(loc='best')

# %% [markdown]
# ### Dataset Preparation

# %%
dataset_total=pd.concat((aaplTrain.Close,dataset_test.Close),axis=0)

# %%
inputs=dataset_total.iloc[len(dataset_total)-len(dataset_test)-120:].values

# %%
inputs=inputs.reshape(-1,1)

# %%
inputs = msc.transform(inputs)

# %%
X_test = []
for i in range(120, len(inputs)):
    X_test.append(inputs[i-120:i, 0])

# %%
X_test=np.array(X_test)

# %%
X_test=X_test.reshape(X_test.shape[0],X_test.shape[1],-1);

# %%
X_test.shape
# Out:
# (41, 120, 1)

# %%
y_pred=grumodel.predict(X_test)
# Out:
# 2/2 [==============================] - 2s 31ms/step

# %%
y_pred_inverse_scaled=msc.inverse_transform(y_pred)

# %%
y_pred_inverse_scaled
predicted=list(y_pred_inverse_scaled.flat)

# %% [markdown]
# ### Visualizing the real vs prediction data

# %%
plt.figure(figsize=(10, 5))
plt.plot(aaplTest.index,aaplTest.Close,label='real-data',color='blue');
plt.plot(aaplTest.index,predicted,label='predicted data', color='red');
plt.legend(loc='best')

# %% [markdown]
# ### Evaluating the GRU- RMSE and relative error

# %%
import math
def rmse(true_values, predicted_values):
    if len(true_values) != len(predicted_values):
        raise ValueError("The lengths of true_values and predicted_values must be the same.")
    squared_errors = [(true - pred) ** 2 for true, pred in zip(true_values, predicted_values)]
    mean_squared_error = sum(squared_errors) / len(true_values)
    rmse_value = math.sqrt(mean_squared_error)
    return rmse_value

rmse=rmse(real_stock_price,predicted)
relative_error= rmse/(max(real_stock_price)-min(real_stock_price))

# %%
print('RMSE: ',round(rmse,3));
print('Percentage of error is: ',round((relative_error[0]*100),3),'%');
# Out:
# RMSE:  5.525
# Percentage of error is:  24.61 %
